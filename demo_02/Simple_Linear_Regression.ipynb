# %% [markdown]
# # Ingresos vs Consumo (income vs consumption)
# ## Simple Linear Regression

# %% [markdown]
# Dos objetivos principales:
# 1. Establecer si hay una relación entre dos variables. Más específicamente, establecer si hay una relación estadísticamente significativa entre dos variables.
# 2. Predecir nuevas observaciones. Puede ser usado aquello que sabemos sobre la relación entre las dos variables para predecir valores que no han sido observados?

# %% [markdown]
# ### Modelo Linear:
#
# El modelo es llamado linear, porque la ecuación representa una linea recta en un gráfico bi-dimensional. Forma:
#
# y = B0 + B1 * X + e
#
# Donde:
#
# * B0 >>> Intercept or constant
# * B1 >>> Is X's slop or coefficient
# * e  >>> The Error term
# * y  >>> Variable dependiente
# * X  >>> Variable independiente

# %% [markdown]
# ## Creación del modelo en python

# %% [markdown]
# ### Correlation

# %%
# Cargar librerias para crear el modelo

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from statsmodels.stats.stattools import durbin_watson

# %%
#Cargar datos

FILE_PATH = "day_1_income_vs_consumption.csv"
df = pd.read_csv(FILE_PATH)

# %%
# Gráfico de dispersion

plt.figure(figsize=(8,6))
plt.scatter(df['income'], df['consumption'], color='blue')
plt.title("Scatterplot - Income vs Consumption")

plt.grid(alpha=0.3)

plt.show()

# %%
# Correlación de Pearsons

correlation = df['income'].corr(df['consumption'])
print(f"Pearson's correlation: {correlation}")
# Out:
# Pearson's correlation: 0.9390731944060711

# %% [markdown]
# ### Linear Model

# %%
# Modelo de regresión lineal

x = df[['income']]
y = df['consumption']

model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
# Resumen del modelo

x_with_const = sm.add_constant(x)
ols_model = sm.OLS(y, x_with_const).fit()
print(ols_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            consumption   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                     283.6
# Date:                Tue, 07 Apr 2026   Prob (F-statistic):           3.24e-19
# Time:                        20:23:43   Log-Likelihood:                -108.41
# No. Observations:                  40   AIC:                             220.8
# Df Residuals:                      38   BIC:                             224.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         49.1334      5.014      9.798      0.000      38.982      59.285
# ...

# %%
# Coeficientes del modelo

print("Intercept: ", model.intercept_)
print("Slope: ", model.coef_[0])
# Out:
# Intercept:  49.133413704883026
# Slope:  0.8527360070677883

# %% [markdown]
# ### Análisis del modelo

# %%
# linea de regresión del gráfico


plt.scatter(df['income'], df['consumption'], color='blue')
plt.plot(df['income'], model.predict(x), color='red', linewidth=1)
plt.title("Scatterplot with Regression Line")
plt.xlabel("Income")
plt.ylabel("Consumption")
plt.show()

# %% [markdown]
# Sobre el problema:
# Está relacionado el ingreso de una familía con la cantidad que consumen?
#
# * El consumo está realmente relacionado con los ingresos
# * La relación entre las dos variábles es lo suficientemente fuerte para declarar que están relacionadas?
# * Pueden ser usados datos de 40 famílias para hacer una predicción de todas las famílias?

# %%
# 8. Intervalos de confianza
confidence_intervals = ols_model.conf_int(alpha=0.05)
print("Confidence intervals:\n", confidence_intervals)
# Out:
# Confidence intervals:
#                  0          1
# const   38.982102  59.284725
# income   0.750237   0.955235

# %% [markdown]
# Interpret the confidence interval

# %%
# 9. Predicciones
new_values = pd.DataFrame({'income': [150, 130, 125]})
point_predictions = model.predict(new_values)
print("Point predictions:\n", point_predictions)
# Out:
# Point predictions:
#  [177.04381477 159.98909462 155.72541459]

# %%
# Predicciones con intervalos de confianza
predictions_with_ci = ols_model.get_prediction(sm.add_constant(new_values)).summary_frame(alpha=0.05)
print("Predictions with confidence intervals:\n", predictions_with_ci)
# Out:
# Predictions with confidence intervals:
#           mean   mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 0  177.043815  2.680889     171.616639     182.470991    167.741414
# 1  159.989095  1.707693     156.532050     163.446139    151.680570
# 2  155.725415  1.472728     152.744032     158.706797    147.603280
#
#    obs_ci_upper
# 0    186.346216
# 1    168.297619
# 2    163.847549

# %%
# Gráfico con predicciones
plt.scatter(df['income'], df['consumption'], color='blue', label='Original data')
plt.scatter(new_values['income'], point_predictions, color='green', s=100, label='Predicted points')
plt.plot(df['income'], model.predict(x), color='red', linewidth=3, label='Regression line')
plt.title("Scatterplot with Predictions")
plt.xlabel("Income")
plt.ylabel("Consumption")
plt.legend()
plt.show()

# %%
# SUPUESTOS

## 1. Linealidad
residuals = y - model.predict(x)
plt.scatter(model.predict(x), residuals)
plt.axhline(0, color='red', linestyle='--')
plt.title("Linearity Check")
plt.xlabel("Predicted values")
plt.ylabel("Residuals")
plt.show()

# %%
## 2. Normalidad de los residuos
sm.qqplot(residuals, line='45', fit=True)
plt.title("Q-Q Plot of Residuals")
plt.show()

# %%
## 3. Homocedasticidad
plt.scatter(model.predict(x), np.abs(residuals))
plt.axhline(0, color='blue', linestyle='--')
plt.title("Homoscedasticity Check")
plt.xlabel("Predicted values")
plt.ylabel("Absolute Residuals")
plt.show()

# %%
## 4. Independencia de los residuos (Durbin-Watson Test)
dw_stat = durbin_watson(residuals)
print(f"Durbin-Watson statistic: {dw_stat}")
# Out:
# Durbin-Watson statistic: 1.9272161565731434
